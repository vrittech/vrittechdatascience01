# %% [markdown]
# # List
#
# ['a', 'b', "c", 1, 2, 3.5]

# %%
a = ['a', 'b', "c", 1, 2, 3.5]

# %%
len(a)
# Out:
# 6

# %%
type(a)
# Out:
# list

# %% [markdown]
# # Indexing

# %%
a[1]
# Out:
# 'b'

# %%
a[-1]
# Out:
# 3.5

# %% [markdown]
# # Slicing

# %%
a[:3]
# Out:
# ['a', 'b', 'c']

# %%
a[:3:2]
# Out:
# ['a', 'c']

# %%
a[::-1]
# Out:
# [3.5, 2, 1, 'c', 'b', 'a']

# %%
a
# Out:
# ['a', 'b', 'c', 1, 2, 3.5]

# %% [markdown]
# # Methods

# %%
a.reverse()
a
# Out:
# [3.5, 2, 1, 'c', 'b', 'a']

# %%
a.index('c')
# Out:
# 3

# %%
a.pop()
# Out:
# 'a'

# %%
a
# Out:
# [3.5, 2, 1, 'c', 'b']

# %%
a.pop(1)
# Out:
# 2

# %%
a
# Out:
# [3.5, 1, 'c', 'b']

# %%
a.remove(1)

# %%
a
# Out:
# [3.5, 'c', 'b']

# %%
a.append(5)

# %%
a
# Out:
# [3.5, 'c', 'b', 5]

# %% [markdown]
# # Updating

# %%
a[2] = 'abc'

# %%
a
# Out:
# [3.5, 'c', 'abc', 5]
