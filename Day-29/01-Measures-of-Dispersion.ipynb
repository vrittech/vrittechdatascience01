# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random numbers from a skewed normal distribution
x = np.random.standard_t(10, size=1000)
x[:15]
# Out:
# array([-0.80991562, -0.15930868,  0.22589242, -1.31444819, -0.83898658,
#         1.01382051,  0.21714375, -1.48017032, -0.51395444,  1.91007197,
#        -1.00432556, -1.00302088,  1.79711073,  1.68705444, -2.38982418])

# %%
plt.hist(x, color = 'blue')
# Out:
# (array([  2.,   9.,  13.,  66., 179., 318., 254., 114.,  38.,   7.]),
#  array([-4.64794449, -3.84272019, -3.03749588, -2.23227157, -1.42704726,
#         -0.62182295,  0.18340136,  0.98862567,  1.79384998,  2.59907429,
#          3.4042986 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Range

# %%
max_value = np.max(x)
min_value = np.min(x)

# %%
print(f"Maximum Value: {max_value}")
print(f"Minimum Value: {min_value}")
# Out:
# Maximum Value: 3.40429859620885
# Minimum Value: -4.647944494402117

# %%
range = max_value - min_value
print(f"Range: {range}")
# Out:
# Range: 8.052243090610968

# %% [markdown]
# ## Inter Quartile Range (IQR)

# %%
q1 = np.percentile(x, 25)
q3 = np.percentile(x, 75)

# %%
iqr = q3 - q1
print("IQR:", iqr)
# Out:
# IQR: 1.364129946041066

# %% [markdown]
# ## Mean Absolute Deviation (MAD)

# %%
mean = x.mean()

# %%
mad = np.mean(np.abs(x - mean)
print("MAD:", mad)
# Out:
# MAD: 0.8361967622538158

# %%
plt.hist(x, color = 'blue')
plt.axvline(x = mad, color='red')
plt.axvline(x = mean, color='yellow')
