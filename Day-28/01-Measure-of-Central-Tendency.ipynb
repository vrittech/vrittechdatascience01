# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
# Generate random numbers from a skewed normal distribution
x = np.random.standard_t(10, size=1000)
x[:15]
# Out:
# array([-1.31363829, -0.64931496,  1.68754188, -0.87840543, -0.23272367,
#        -0.57444806, -1.70173855,  1.02494438, -0.03024445,  0.59605745,
#        -1.07706989, -1.06794968, -1.40660805, -0.99878573, -1.03472214])

# %%
plt.hist(x, color = 'blue')
# Out:
# (array([  9.,  26.,  81., 190., 278., 246., 119.,  40.,   8.,   3.]),
#  array([-3.52817547, -2.78157751, -2.03497954, -1.28838158, -0.54178361,
#          0.20481435,  0.95141231,  1.69801028,  2.44460824,  3.19120621,
#          3.93780417]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Mean

# %%
mean = np.mean(x)
print("Mean:", mean)
# Out:
# Mean: -0.031120859737741452

# %%
plt.hist(x, color = 'blue')
plt.axvline(x = mean, color='yellow')

# %% [markdown]
# ## Median

# %%
median = np.median(x)
print("Median:", median)
# Out:
# Median: -0.04746892244151858

# %%
plt.hist(x, color = 'blue')
plt.axvline(x = median, color='yellow')

# %% [markdown]
# ## Mode

# %%
mode = stats.mode(x).mode
print("Mode:", mode)
# Out:
# Mode: [-3.52817547]
# /tmp/ipykernel_23862/3231607848.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode = stats.mode(x).mode

# %%
plt.hist(x, color = 'blue')
plt.axvline(x = mode, color='yellow')
